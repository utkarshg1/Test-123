# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ![image.png](attachment:f8a70925-1224-4cee-8a12-3e1ebdd58fd7.png)

# %% [markdown]
# ### Step 1 - Data Ingestion

# %%
path = r"C:\ETLHive lectures by me\Datasets\laptopPrice.csv"
print(path)
# Out:
# C:\ETLHive lectures by me\Datasets\laptopPrice.csv

# %%
import pandas as pd
df = pd.read_csv(path)

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# 0          No       No  34649  2 stars                  3                  0
# 1          No       No  38999  3 stars                 65                  5
# 2          No       No  39999  3 stars                  8                  1
# 3          No       No  69990  3 stars                  0                  0
# 4          No       No  26990  3 stars                  0                  0

# %% [markdown]
# ### Step 2 - Perform basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
#  16  rating             823 non-null    object
#  17  Number of Ratings  823 non-null    int64
#  18  Number of Reviews  823 non-null    int64
# dtypes: int64(3), object(16)
# memory usage: 122.3+ KB

# %%
df.isna().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 21

# %%
# Drop the duplicates
df = df.drop_duplicates(keep="first").reset_index(drop=True)
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 797    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 798    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 799    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 800    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 801  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 797  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 798  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 799  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 800  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 801   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 797       1 year          No       No  135990  3 stars                  0
# 798       1 year          No       No  144990  3 stars                  0
# 799       1 year          No       No  149990  3 stars                  0
# 800       1 year          No       No  142990  3 stars                  0
# 801  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 797                  0
# 798                  0
# 799                  0
# 800                  0
# 801                  4
#
# [802 rows x 19 columns]

# %%
df.shape
# Out:
# (802, 19)

# %% [markdown]
# ### Step 3- Descripctive statistics

# %%
df.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
cat = list(df.columns[df.dtypes == "object"])
cat
# Out:
# ['brand',
#  'processor_brand',
#  'processor_name',
#  'processor_gnrtn',
#  'ram_gb',
#  'ram_type',
#  'ssd',
#  'hdd',
#  'os',
#  'os_bit',
#  'graphic_card_gb',
#  'weight',
#  'warranty',
#  'Touchscreen',
#  'msoffice',
#  'rating']

# %%
con = list(df.columns[df.dtypes != "object"])
con
# Out:
# ['Price', 'Number of Ratings', 'Number of Reviews']

# %%
df[con].describe().T
# Out:
#                    count          mean           std      min      25%  \
# Price              802.0  76625.543641  45232.984422  16990.0  45990.0
# Number of Ratings  802.0    299.844140   1001.784420      0.0      0.0
# Number of Reviews  802.0     36.089776    118.313553      0.0      0.0
#
#                        50%       75%       max
# Price              63990.0  89525.00  441990.0
# Number of Ratings     17.0    140.25   15279.0
# Number of Reviews      2.0     18.00    1947.0

# %%
df[cat].describe().T
# Out:
#                 count unique      top freq
# brand             802      8     ASUS  243
# processor_brand   802      3    Intel  594
# processor_name    802     11  Core i5  284
# processor_gnrtn   802      8     11th  328
# ram_gb            802      4     8 GB  404
# ram_type          802      6     DDR4  690
# ssd               802      7   512 GB  389
# hdd               802      4     0 GB  602
# os                802      3  Windows  763
# os_bit            802      2   64-bit  693
# graphic_card_gb   802      5     0 GB  557
# weight            802      3   Casual  509
# warranty          802      4   1 year  498
# Touchscreen       802      2       No  706
# msoffice          802      2       No  522
# rating            802      5  4 stars  437

# %%
df["brand"].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
df["brand"].value_counts()
# Out:
# brand
# ASUS      243
# DELL      149
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      23
# Avita       6
# Name: count, dtype: int64

# %% [markdown]
# ### Step 4 - Data Visualization
# 1. Univariate
# 2. Bivariate
# 3. Multivariate

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Univariate
# 1. Categorical - Countplot
# 2. Continous - Histograms

# %%
cat
# Out:
# ['brand',
#  'processor_brand',
#  'processor_name',
#  'processor_gnrtn',
#  'ram_gb',
#  'ram_type',
#  'ssd',
#  'hdd',
#  'os',
#  'os_bit',
#  'graphic_card_gb',
#  'weight',
#  'warranty',
#  'Touchscreen',
#  'msoffice',
#  'rating']

# %%
sns.countplot(data=df, x="processor_brand")
# Out:
# <Axes: xlabel='processor_brand', ylabel='count'>

# %%
plt.figure(figsize=(10, 4))
sns.countplot(data=df, x="processor_brand") # Plotting the countplot
plt.title("Countplot for Processor Brand") # Add a title
plt.show() # Show the plot

# %%
for i in cat:
    plt.figure(figsize=(10, 4))
    sns.countplot(data=df, x=i)
    plt.title(f"Countplot for {i}")
    plt.show()

# %% [markdown]
# ### Histogram - Continous features

# %%
con
# Out:
# ['Price', 'Number of Ratings', 'Number of Reviews']

# %%
sns.histplot(data=df, x="Price")
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
# kde - Kernel Density Estimate

# %%
plt.figure(figsize=(10, 4))
sns.histplot(data=df, x="Price", kde=True)
plt.title("Histogram for Price")
plt.show()

# %%
for i in con:
    plt.figure(figsize=(10, 4))
    sns.histplot(data=df, x=i, kde=True)
    plt.title(f"Histogram for {i}")
    plt.show()

# %% [markdown]
# ### Find out average price by brand

# %%
a = df.groupby(by="brand") \
    .agg({"Price":"mean"}) \
    .sort_values(by="Price")
a
# Out:
#                 Price
# brand
# Avita    56346.500000
# DELL     60788.953020
# acer     72420.039216
# Lenovo   72920.208333
# HP       73640.272059
# ASUS     79426.020576
# MSI      98713.020000
# APPLE   157081.304348

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a.plot(kind="barh", figsize=(8, 3))
plt.show()

# %% [markdown]
# ### 2. Bivariate
# Continuous - Numerical , Categorical - Text
# Analyse 2 features togethor
# 1. Continuous vs Contionuos - Scatterplot , Regplot
# 2. Categorical vs Continuous - Boxplots
# 3. Categorical vs Categorical - Crosstab Heatmap

# %% [markdown]
# ![image.png](attachment:efc7f114-dcde-4a91-b6b9-5b8230a07baa.png)

# %%
con
# Out:
# ['Price', 'Number of Ratings', 'Number of Reviews']

# %%
# Price vs Number of ratings
sns.scatterplot(data=df, x="Number of Ratings", y="Price")
# Out:
# <Axes: xlabel='Number of Ratings', ylabel='Price'>

# %% [markdown]
# ### Number of ratings and price are not related
# ### Higher the ratings lower the price

# %%
cat
# Out:
# ['brand',
#  'processor_brand',
#  'processor_name',
#  'processor_gnrtn',
#  'ram_gb',
#  'ram_type',
#  'ssd',
#  'hdd',
#  'os',
#  'os_bit',
#  'graphic_card_gb',
#  'weight',
#  'warranty',
#  'Touchscreen',
#  'msoffice',
#  'rating']

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df, x="Number of Ratings", y="Price", hue="ram_gb")
plt.title("Price vs Number of Ratings")
plt.grid()
plt.show()

# %%
# Number of reviews vs price
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df, x="Number of Reviews", y="Price", hue="warranty")
plt.title("Number of reviews vs Price")
plt.grid()
plt.show()

# %%
# Number of reviews vs number of ratings
plt.figure(figsize=(8,4))
sns.scatterplot(data=df, x="Number of Ratings", y="Number of Reviews")
plt.title("Number of ratings vs reviews")
plt.grid()
plt.show()

# %% [markdown]
# ### There is linear relationship between number ratings and reviews
# ### Regplot

# %%
plt.figure(figsize=(8, 4))
sns.regplot(data=df, x="Number of Ratings", y="Number of Reviews", line_kws={"color":"red"})
plt.title("Regression Plot for Ratings vs Reviews")
plt.grid()
plt.show()

# %% [markdown]
# ### 2. Categorical vs Continuous
# Box Plot
# ![image.png](attachment:5107847e-7b78-4b67-b1f2-d0fcb614e2ce.png)

# %%
cat
# Out:
# ['brand',
#  'processor_brand',
#  'processor_name',
#  'processor_gnrtn',
#  'ram_gb',
#  'ram_type',
#  'ssd',
#  'hdd',
#  'os',
#  'os_bit',
#  'graphic_card_gb',
#  'weight',
#  'warranty',
#  'Touchscreen',
#  'msoffice',
#  'rating']

# %%
con
# Out:
# ['Price', 'Number of Ratings', 'Number of Reviews']

# %%
df["processor_brand"].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
sns.boxplot(data=df, x="processor_brand", y="Price")
# Out:
# <Axes: xlabel='processor_brand', ylabel='Price'>

# %% [markdown]
# ### Max = Q3 + 1.5*IQR
# ### Min = Q1 - 1.5*IQR

# %% [markdown]
# ### Boxplot for all features with price

# %%
for i in cat:
    plt.figure(figsize=(8, 4))
    sns.boxplot(data=df, x=i, y="Price")
    plt.title(f"Price vs {i} Boxplot")
    plt.show()

# %% [markdown]
# ### Categorical vs Categorical
# Crosstab heatmap

# %%
cat
# Out:
# ['brand',
#  'processor_brand',
#  'processor_name',
#  'processor_gnrtn',
#  'ram_gb',
#  'ram_type',
#  'ssd',
#  'hdd',
#  'os',
#  'os_bit',
#  'graphic_card_gb',
#  'weight',
#  'warranty',
#  'Touchscreen',
#  'msoffice',
#  'rating']

# %%
len(cat)
# Out:
# 16

# %%
16*16
# Out:
# 256

# %%
ctab1 = pd.crosstab(df["ram_gb"], df["ram_type"])
ctab1
# Out:
# ram_type  DDR3  DDR4  DDR5  LPDDR3  LPDDR4  LPDDR4X
# ram_gb
# 16 GB        2   140     2       8       1       20
# 32 GB        0     2     0       0       0        0
# 4 GB         0   197     4       0      10       12
# 8 GB         5   351     2       6      16       24

# %%
sns.heatmap(data= ctab1, annot=True, fmt="d")
plt.title("Ram gb vs Ram type")
plt.show()

# %%
ctab2 = pd.crosstab(df["rating"], df["warranty"])
ctab2
# Out:
# warranty  1 year  2 years  3 years  No warranty
# rating
# 1 star         2        0        0            0
# 2 stars        3        0        0            6
# 3 stars      173        3       10          152
# 4 stars      309       19        3          106
# 5 stars       11        1        0            4

# %%
sns.heatmap(data=ctab2, annot=True, fmt="d")
plt.title("Warranty vs Rating")
plt.show()

# %% [markdown]
# ## Multivariate analysis
# 1. Correlation heatmap
# 2. Pairplot

# %%
con
# Out:
# ['Price', 'Number of Ratings', 'Number of Reviews']

# %%
sns.pairplot(data=df)
plt.show()

# %%
sns.pairplot(data=df, hue="processor_brand")
plt.show()

# %%
path2 = r"C:\ETLHive lectures by me\Datasets\iris.csv"
df2 = pd.read_csv(path2)
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data=df2, hue="species")

# %%
sns.pairplot(data=df, hue="ram_gb")
plt.show()

# %% [markdown]
# ### Correlation heatmap

# %%
c = df.corr(numeric_only=True)
c
# Out:
#                       Price  Number of Ratings  Number of Reviews
# Price              1.000000          -0.152553          -0.156791
# Number of Ratings -0.152553           1.000000           0.991062
# Number of Reviews -0.156791           0.991062           1.000000

# %%
sns.heatmap(data=c, annot=True, fmt=".4f")
# Out:
# <Axes: >

# %% [markdown]
# ### Extra

# %% [markdown]
# ### Median price of laptop by processor brand

# %%
b = df.groupby(by = "processor_brand") \
    .agg({"Price":"median"}) \
    .sort_values(by="Price")
b
# Out:
#                     Price
# processor_brand
# Intel             61793.5
# AMD               68500.0
# M1               131990.0

# %%
b.plot(kind="barh", figsize=(8, 4))
# Out:
# <Axes: ylabel='processor_brand'>

# %% [markdown]
# ### Find out average price of laptops by processor_brand and warranty

# %%
d = df.groupby(by = ["processor_brand", "warranty"]) \
    .agg({"Price":"mean"}) \
    .sort_values(by="Price")

# %%
d = d.round(2)
d
# Out:
#                                  Price
# processor_brand warranty
# Intel           2 years       68945.87
#                 1 year        73326.99
# AMD             No warranty   73547.52
# Intel           No warranty   74241.80
# AMD             1 year        77824.30
#                 3 years       78588.00
# Intel           3 years      113477.20
# M1              1 year       153726.84

# %%
d.plot(kind="barh", figsize=(8, 4))
# Out:
# <Axes: ylabel='processor_brand,warranty'>

# %%
g = pd.pivot_table(
    data= df,
    values = "Price",
    index = "processor_brand",
    columns= "warranty",
    aggfunc= "mean"
)

# %%
g = g.round(2)
g
# Out:
# warranty            1 year   2 years   3 years  No warranty
# processor_brand
# AMD               77824.30       NaN   78588.0     73547.52
# Intel             73326.99  68945.87  113477.2     74241.80
# M1               153726.84       NaN       NaN          NaN

# %%
g.plot(kind="barh", figsize=(8, 4))
# Out:
# <Axes: ylabel='processor_brand'>

# %% [markdown]
# ### Quick EDA

# %%
# %pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.12.1-py2.py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (3.8.4)
# Requirement already satisfied: pydantic>=2 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (2.5.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (3.1.4)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling)
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (1.26.4)
# Collecting htmlmin==0.1.12 (from ydata-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling)
#   Downloading phik-0.12.4-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (2.32.2)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (4.66.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (0.14.2)
# Collecting typeguard<5,>=3 (from ydata-profiling)
#   Downloading typeguard-4.4.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling)
#   Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numba<1,>=0.56.0 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (0.59.1)
# Requirement already satisfied: PyWavelets in c:\users\admin\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (1.5.0)
# Requirement already satisfied: pillow in c:\users\admin\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\admin\anaconda3\lib\site-packages (from numba<1,>=0.56.0->ydata-profiling) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\admin\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\admin\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\admin\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.6.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\admin\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\admin\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.2.1)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Downloading ydata_profiling-4.12.1-py2.py3-none-any.whl (390 kB)
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.4-cp312-cp312-win_amd64.whl (666 kB)
#    ---------------------------------------- 0.0/666.4 kB ? eta -:--:--
#    --------------------------------------- 666.4/666.4 kB 13.0 MB/s eta 0:00:00
# Downloading typeguard-4.4.1-py3-none-any.whl (35 kB)
# Downloading visions-0.7.6-py3-none-any.whl (104 kB)
# Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl (301 kB)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27092 sha256=3b83fbac38f8e55e744142164847df515e75b168cdc52d13bec9ae22d1fbcdf7
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\5f\d4\d7\4189b07b5902ee9f3ce0dbb14909fbe8037c39d6c63ffd49c9
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, multimethod, dacite, imagehash, wordcloud, visions, phik, ydata-profiling
# Successfully installed dacite-1.8.1 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.12 phik-0.12.4 typeguard-4.4.1 visions-0.7.6 wordcloud-1.9.4 ydata-profiling-4.12.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Laptop prices report")

# %%
import os
path3 = r"C:\report"
os.chdir(path3)

# %%
profile.to_file("laptop_report.html")
# Out:
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
